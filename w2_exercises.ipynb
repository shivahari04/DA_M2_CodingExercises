# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
"genre": [
    "Pop","Rock","Hip-Hop","Electronic","Pop","Rock","Hip-Hop","Electronic",
    "Pop","Rock","Hip-Hop","Electronic","Pop","Rock","Hip-Hop","Electronic",
    "Pop","Rock","Hip-Hop","Electronic"
],
"streams": [
    120,90,150,70,130,95,140,80,
    110,85,155,75,125,100,145,78,
    118,92,160,82
],
"likes": [
    30,20,50,15,35,22,48,18,
    28,19,55,16,32,25,47,17,
    29,21,60,19
],
"shares": [
    10,8,20,5,12,9,18,6,
    9,7,22,5,11,10,19,6,
    10,8,25,7
],
"year": [
    2020,2020,2020,2020,2021,2021,2021,2021,
    2022,2022,2022,2022,2023,2023,2023,2023,
    2024,2024,2024,2024
]
}

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#         genre  streams  likes  shares  year
# 0         Pop      120     30      10  2020
# 1        Rock       90     20       8  2020
# 2     Hip-Hop      150     50      20  2020
# 3  Electronic       70     15       5  2020
# 4         Pop      130     35      12  2021

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   genre    20 non-null     str
#  1   streams  20 non-null     int64
#  2   likes    20 non-null     int64
#  3   shares   20 non-null     int64
#  4   year     20 non-null     int64
# dtypes: int64(4), str(1)
# memory usage: 932.0 bytes

# %%
avg_streams = df.groupby('genre')['streams'].mean().sort_values(ascending=False)
avg_streams
# Out:
# genre
# Hip-Hop       150.0
# Pop           120.6
# Rock           92.4
# Electronic     77.0
# Name: streams, dtype: float64

# %% [markdown]
# #Create a Bar Plot
#
# x-axis: genre
# y-axis: streams
# title: Streams by Genre

# %%
plt.Figure(figsize=(4,4))

plt.bar(avg_streams.index, avg_streams.values)

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.xlabel('Genre')
plt.ylabel('Streams')
plt.title('Streams by Genre')
plt.xticks(rotation =90)



plt.tight_layout()
plt.show()

# %% [markdown]
# # Create a Scatter Plot
# x-axis: likes
# y-axis: streams
# title: Streams vs Likes

# %%
plt.figure(figsize=(10,6)) 
plt.scatter(df['likes'],df['streams'])
plt.xlabel('Likes')
plt.ylabel('Streams')
plt.title('Streams vs Likes')

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# #Create a Histogram
#
# Use streams column
# Title: Streams Distribution

# %%
#Stream Distribution

plt.Figure(figsize=(10,6))
plt.hist(df["streams"])
plt.xlabel('Streams')

plt.title('Streams Distribution', fontsize = 15)

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
